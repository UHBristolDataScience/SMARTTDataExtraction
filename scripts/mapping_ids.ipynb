# %% [markdown]
# ### Mapping variable IDs...
#
# # TODO:
# * make this so it can run SQL queries directly to ICCA - to get attributes
# * add config file that defined name or server and database (and table names?). instruct user to set these first.
# * add instructions for setup and running streamlit app. (maybe remove jupyerlab?)
# * write a python script that will run all the initial SQL queries (to get intervention that are in use in each table) and save them to `data/` directory.
#
# #### The procedure is:
# - run script(s) to produce complete intervention tables for each db table (e.g. PtAssessment)
# - use search strings to query those tables for each variable of interest, selecting relevant interventionIds manually
# - for each interventionId requested, run a query to produce example data with each attribute for that intervention
# - review outputs manually and select intervention/attribute pairs, giving a name to each and adding any comments as free text
# - save these in a suitable formate (one that allows to check for completeness)
#
# #### Notes:
#
# - In some cases there may be many unrelated or irrelevant interventions pciked up by our search strings. This is the price we pay for trying tn esnure that our search is not missing anything!

# %%
import pandas as pd
import pyodbc
from functools import reduce
import numpy as np

# %%
schema = pd.read_excel(
    '../schema/smartt_variable_definitions.xlsx', 
    sheet_name='search_strings'
)

# %%
schema.head()
# Out:
#               Variable Simple name                      Search Strings  \
# 0     Age at admission         age                                 age
# 1               Gender      gender                              gender
# 2  Weight at admission      weight                              weight
# 3    Origin department  admit_from  admit, origin, admission, location
# 4                   pH          ph                                  ph
#
#   Likely ICCA table  Possibly derived  \
# 0    PtDemographics              True
# 1    PtDemographics             False
# 2    PtDemographics              True
# 3                 ?              True
# 4      PtLabResults             False
#
#                               Pacmed ontology   Snowmed CT Notes
# 0  General_information.Patient_characteristics         NaN   NaN
# 1  General_information.Patient_characteristics         NaN   NaN
# 2  General_information.Patient_characteristics         NaN   NaN
# 3    General_information.Admission_information         NaN   NaN
# 4        Laboratory_results.Blood_gas_analysis         NaN   NaN

# %%
interventions = pd.read_csv('../data/all_ptassessment_interventions_units_5_8_9.rpt', sep='\t')
interventions.dropna(axis=0, subset=['shortLabel', 'longLabel'], inplace=True)
interventions.head()
# Out:
#   interventionId               shortLabel  \
# 1           1746  Airway Respiratory Rate
# 2           1793                    RVSWI
# 3           1798                    LVSWI
# 4           1830             Glasgow Coma
# 5           1844                     LCWI
#
#                              longLabel  conceptCode  numberOfPatients  \
# 1              Airway Respiratory Rate   86290005.0           53345.0
# 2  Right Ventricular Stroke Work Index  277380003.0             875.0
# 3   Left Ventricular Stroke Work Index  276898003.0             464.0
# 4                   Glasgow Coma Scale  386554004.0         2751747.0
# 5              Left Cardiac Work Index  399266005.0             480.0
#
#             firstChartTime            lastChartTime  numberOfRecords  \
# 1  2015-02-03 12:00:00.000  2016-05-30 15:00:00.000          53345.0
# 2  2015-05-26 17:55:00.000  2023-06-08 08:00:00.000            875.0
# 3  2015-05-26 17:55:00.000  2023-06-08 13:00:00.000            464.0
# 4  2015-02-03 10:00:00.000  2023-08-10 00:00:00.000        2751747.0
# 5  2015-05-26 17:55:00.000  2023-06-08 13:00:00.000            480.0
#
#    minClinicalUnitId  maxClinicalUnitId
# 1                5.0                5.0
# 2                5.0                8.0
# 3                5.0                8.0
# 4                5.0                9.0
# 5                5.0                8.0

# %%
variables = list(schema.Variable)
print(f"There are {len(variables)} variables in the schema.")
# Out:
# There are 65 variables in the schema.

# %%
variable_id = 0

# %%
search_strings = schema.loc[variable_id]['Search Strings'].split(',')

# %%
logical_index = np.logical_or.reduce(
    [
        interventions.longLabel.str.contains(search_string, case=False)
        for search_string in search_strings
    ]
)

# %%
display_cols = ['interventionId', 'shortLabel', 'longLabel', 'numberOfPatients', 'firstChartTime', 'firstChartTime']
interventions[logical_index][display_cols]
# Out:
#      interventionId                        shortLabel  \
# 20             2016                   Temp Management
# 86             2912  Respiratory Management Prescribe
# 140            2971                  Management Plan:
# 145            2978            Management Plan Other:
# 177            3016     Nutrition Management (Day 3):
# 179            3018   Respiratory Management (Day 4):
# 219            3078                 Drainage Variance
# 225            3085  Record Drainage from Arm/Leg Dra
# 236            3096        Continue Fluid Management:
# 240            3100        Fluid Management Variance:
# 250            3110   PostExtubationEncourageComments
# 267            3128                        Encourage:
# 291            3153         Nutrition Management Day1
# 303            3168    Nutrition Management Variance:
# 304            3169  CardiovascularManagementVariance
# 312            3177  Respiratory Management Variance:
# 392            3304       Speech and Language Therapy
# 644            4908   Bowel Management System 28 Days
# 1227          34891       Patient has any skin damage
# 1262          43286     Speech & Languages Therapist:
# 1383          68282   Male or female aged 18 years or
# 1492          68559        Details of pressure damage
# 1506          68581  Does patient have pressure damag
# 1661          69141              Pain managed (<4/10)
# 1670          69187      Continence/ Fluid Management
# 1708          69233             Details of Management
# 1904          71534  Age <61yrs AND sudden cardiac de
# 1978          72111  Age <61yrs AND sudden cardiac de
# 2022          73154                      Skin Damage?
#
#                                               longLabel  numberOfPatients  \
# 20                               Temperature Management          420378.0
# 86                    Respiratory Management Prescribed             353.0
# 140                                    Management Plan:           51753.0
# 145                              Management Plan Other:            2872.0
# 177                       Nutrition Management (Day 3):           13118.0
# 179                     Respiratory Management (Day 4):            6334.0
# 219                                   Drainage Variance             627.0
# 225                 Record Drainage from Arm/Leg Drain?            2664.0
# 236                          Continue Fluid Management:            3348.0
# 240                          Fluid Management Variance:            9920.0
# 250                  Post Extubation Encourage Comments             381.0
# 267                                          Encourage:            7260.0
# 291                           Nutrition Management Day1           27139.0
# 303                      Nutrition Management Variance:            7055.0
# 304                 Cardiovascular Management Variance:            9642.0
# 312                    Respiratory Management Variance:            9505.0
# 392                         Speech and Language Therapy            9220.0
# 644                   Bowel Management System (28 Days)            1121.0
# 1227                 Does patient have any skin damage?             414.0
# 1262                      Speech & Languages Therapist:             616.0
# 1383              Male or female aged 18 years or above               1.0
