# %% [markdown]
# ### Mapping variable IDs...
#
# # TODO:
# * make this so it can run SQL queries directly to ICCA - to get attributes
# * add config file that defined name or server and database (and table names?). instruct user to set these first.
# * add instructions for setup and running streamlit app. (maybe remove jupyerlab?)
# * write a python script that will run all the initial SQL queries (to get intervention that are in use in each table) and save them to `data/` directory.
#
# #### The procedure is:
# - run script(s) to produce complete intervention tables for each db table (e.g. PtAssessment)
# - use search strings to query those tables for each variable of interest, selecting relevant interventionIds manually
# - for each interventionId requested, run a query to produce example data with each attribute for that intervention
# - review outputs manually and select intervention/attribute pairs, giving a name to each and adding any comments as free text
# - save these in a suitable formate (one that allows to check for completeness)
#
# #### Notes:
#
# - In some cases there may be many unrelated or irrelevant interventions pciked up by our search strings. This is the price we pay for trying tn esnure that our search is not missing anything!

# %%
import pandas as pd
import pyodbc
from functools import reduce
import numpy as np

# %%
schema = pd.read_excel(
    '../schema/smartt_variable_definitions.xlsx', 
    sheet_name='search_strings'
)

# %%
schema.head(45)
# Out:
#                                   Variable  Simple name  \
# 0                         Age at admission          age
# 1                                   Gender       gender
# 2                      Weight at admission       weight
# 3                        Origin department   admit_from
# 4                                       pH           ph
# 5                                    Paco2        paco2
# 6                                     Pao2         pao2
# 7                       actual bicarbonate         hco3
# 8                              base excess  base_excess
# 9               arterial oxygen saturation          so2
# 10                              Hemoglobin  haemoglobin
# 11                               WBC count          wbc
# 12                          platelet count    platelets
# 13   activated partial thromboplastin time         aptt
# 14                        prothrombin time           pt
# 15                                  Sodium           na
# 16                               potassium            k
# 17                              creatinine   creatinine
# 18                                    urea         urea
# 19                   urea/creatinine ratio       bun/cr
# 20                                chloride     chloride
# 21                         ionized calcium          ica
# 22                               magnesium           mg
# 23                               phosphate          po4
# 24                   lactate dehydrogenase          ldh
# 25                                 glucose      glucose
# 26                                 lactate      lactate
# 27                      C-reactive protein          crp
# 28                                 albumin      albumin
# 29                       Creatinine kinase           ck
# 30                              troponin-T         ctnt
# 31                               Bilirubin    bilirubin
# 32                alanine aminotransferase          alt
# 33              aspartate aminotransferase          ast
# 34                    alkaline phosphatase          alp
# 35               Gamma-glutamyltransferase          ggt
# 36                                 amylase      amylase
# 37                              Heart rate           hr
# 38      arterial blood pressure (systolic)          sap
# 39     arterial blood pressure (diastolic)          dap
# 40          arterial blood pressure (mean)          map
# 41   noninvasive blood pressure (systolic)          sbp
# 42  noninvasive blood pressure (diastolic)          dbp
# 43                          cardiac output           co
# 44                             temperature         temp
#
#                                        Search Strings Likely ICCA table  \
# 0                                                 age    PtDemographics
# 1                                              gender    PtDemographics
# 2                                              weight    PtDemographics
# 3                  admit, origin, admission, location                 ?
# 4                                                  ph      PtLabResults
# 5                          paco2, co2, carbon dioxide      PtLabResults
# 6                                    pao2, o2, oxygen      PtLabResults
# 7      bicarbonate, hco3, bicarb, co2, carbon dioxide      PtLabResults
# 8                               base excess, base, BE      PtLabResults
# 9                        saturation, sao2, so2, o2sat      PtLabResults
# 10                        hemoglobin, haemoglobin, hb      PtLabResults
# 11                              white, wbc, leukocyte      PtLabResults
# 12                              platelet, thrombocyte      PtLabResults
# 13                                ptt, thromboplastin      PtLabResults
# 14                          prothrombin, pt, pro time      PtLabResults
# 15                                         na, sodium      PtLabResults
# 16                                       potassium, K      PtLabResults
# 17                                creatinine, cr, scr      PtLabResults
# 18                                   urea, BUN, ureum      PtLabResults
# 19              urea, BUN, ureum, creatinine, cr, scr      PtLabResults
# 20                                       chloride, cl      PtLabResults
# 21               ica, calcium, free, ionized, ionised      PtLabResults
# 22                                 mg, mag, magnesium      PtLabResults
# 23      phosphate, po4, phos, phosphorous, phosphorus      PtLabResults
# 24      lactate dehydrogenase, ldh, ld, dehydrogenase      PtLabResults
# 25                                       glucose, glu      PtLabResults
# 26                               lactate, lactic acid      PtLabResults
# 27                           crp, c-reactive, protein      PtLabResults
# 28                                       alb, albumin      PtLabResults
# 29                                ck, cpk, creatinine      PtLabResults
# 30                                tnt, ctnt, troponin      PtLabResults
# 31                                     bilirubin, bil      PtLabResults
# 32                                 alt, sgpt, alanine      PtLabResults
# 33                               ast, aspartate, sgot      PtLabResults
# 34                                      alp, alkaline      PtLabResults
# 35                                         gamma, ggt      PtLabResults
# 36                                       amylase, amy      PtLabResults
# 37                                          heart, hr      PtAssessment
# 38             systolic, arterial, pressure, sap, abp      PtAssessment
# 39            diastolic, arterial, pressure, dap, abp      PtAssessment
# 40                 mean, arterial, pressure, map, abp      PtAssessment
# 41  nbp, nibp, noninvasive, non-invasive, pressure...      PtAssessment
# 42  nbp, nibp, noninvasive, non-invasive, pressure...      PtAssessment
# 43                                 cardiac output, co      PtAssessment
# 44                                  temperature, temp      PtAssessment
#
#     Possibly derived                             Pacmed ontology   Snowmed CT  \
# 0               True  General_information.Patient_characteristics         NaN
# 1              False  General_information.Patient_characteristics         NaN
# 2               True  General_information.Patient_characteristics         NaN
# 3               True    General_information.Admission_information         NaN
# 4              False        Laboratory_results.Blood_gas_analysis         NaN
# 5              False        Laboratory_results.Blood_gas_analysis         NaN
# 6              False        Laboratory_results.Blood_gas_analysis         NaN
# 7              False        Laboratory_results.Blood_gas_analysis         NaN
# 8              False        Laboratory_results.Blood_gas_analysis         NaN
# 9              False        Laboratory_results.Blood_gas_analysis         NaN
# 10             False                Laboratory_results.Hematology         NaN
# 11             False                Laboratory_results.Hematology         NaN
# 12             False                Laboratory_results.Hematology         NaN
# 13             False                Laboratory_results.Hematology         NaN
# 14             False                Laboratory_results.Hematology         NaN
# 15             False         Laboratory_results.Routine_chemistry         NaN
# 16             False         Laboratory_results.Routine_chemistry         NaN
# 17             False         Laboratory_results.Routine_chemistry         NaN
# 18             False         Laboratory_results.Routine_chemistry         NaN
# 19             False         Laboratory_results.Routine_chemistry         NaN
# 20             False         Laboratory_results.Routine_chemistry         NaN
# 21             False         Laboratory_results.Routine_chemistry         NaN
# 22             False         Laboratory_results.Routine_chemistry         NaN
# 23             False         Laboratory_results.Routine_chemistry         NaN
# 24             False         Laboratory_results.Routine_chemistry         NaN
# 25             False         Laboratory_results.Routine_chemistry         NaN
# 26             False         Laboratory_results.Routine_chemistry         NaN
# 27             False         Laboratory_results.Routine_chemistry         NaN
# 28             False         Laboratory_results.Routine_chemistry         NaN
# 29             False           Laboratory_results.Cardiac_enzymes         NaN
# 30             False           Laboratory_results.Cardiac_enzymes         NaN
# 31             False  Laboratory_results.Liver_and_pancreas_tests         NaN
# 32             False  Laboratory_results.Liver_and_pancreas_tests         NaN
# 33             False  Laboratory_results.Liver_and_pancreas_tests         NaN
# 34             False  Laboratory_results.Liver_and_pancreas_tests         NaN
# 35             False  Laboratory_results.Liver_and_pancreas_tests         NaN
# 36             False  Laboratory_results.Liver_and_pancreas_tests         NaN
# 37             False      Vital_signs_and_device_data.Circulation         NaN
# 38             False      Vital_signs_and_device_data.Circulation         NaN
# 39             False      Vital_signs_and_device_data.Circulation         NaN
# 40             False      Vital_signs_and_device_data.Circulation         NaN
# 41             False      Vital_signs_and_device_data.Circulation         NaN
# 42             False      Vital_signs_and_device_data.Circulation         NaN
# 43              True      Vital_signs_and_device_data.Circulation         NaN
# 44             False      Vital_signs_and_device_data.Circulation         NaN
#
#                                                 Notes
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   Should we include/combine SpO2 in this variabl...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  This ratio is the other way round in the US. I...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                       Check various glucose tests.
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN

# %%
interventions = pd.read_csv('../data/all_ptassessment_interventions_units_5_8_9.rpt', sep='\t')
interventions.dropna(axis=0, subset=['shortLabel', 'longLabel'], inplace=True)
interventions.head()
# Out:
#   interventionId               shortLabel  \
# 1           1746  Airway Respiratory Rate
# 2           1793                    RVSWI
# 3           1798                    LVSWI
# 4           1830             Glasgow Coma
# 5           1844                     LCWI
#
#                              longLabel  conceptCode  numberOfPatients  \
# 1              Airway Respiratory Rate   86290005.0           53345.0
# 2  Right Ventricular Stroke Work Index  277380003.0             875.0
# 3   Left Ventricular Stroke Work Index  276898003.0             464.0
# 4                   Glasgow Coma Scale  386554004.0         2751747.0
# 5              Left Cardiac Work Index  399266005.0             480.0
#
#             firstChartTime            lastChartTime  numberOfRecords  \
# 1  2015-02-03 12:00:00.000  2016-05-30 15:00:00.000          53345.0
# 2  2015-05-26 17:55:00.000  2023-06-08 08:00:00.000            875.0
# 3  2015-05-26 17:55:00.000  2023-06-08 13:00:00.000            464.0
# 4  2015-02-03 10:00:00.000  2023-08-10 00:00:00.000        2751747.0
# 5  2015-05-26 17:55:00.000  2023-06-08 13:00:00.000            480.0
#
#    minClinicalUnitId  maxClinicalUnitId
# 1                5.0                5.0
# 2                5.0                8.0
# 3                5.0                8.0
# 4                5.0                9.0
# 5                5.0                8.0

# %%
variables = list(schema.Variable)
print(f"There are {len(variables)} variables in the schema.")
# Out:
# There are 65 variables in the schema.

# %%
variable_id = 41

# %%
search_strings = [
    s.strip()
    for s in 
    schema.loc[variable_id]['Search Strings'].split(',')
]

# %%
search_strings
# Out:
# ['nbp', 'nibp', 'noninvasive', 'non-invasive', 'pressure', 'systolic']

# %%
logical_index = np.logical_or.reduce(
    [
        interventions.longLabel.str.contains(search_string, case=False)
        for search_string in search_strings
    ]
)

# %%
display_cols = ['interventionId', 'shortLabel', 'longLabel', 'numberOfPatients', 'firstChartTime', 'firstChartTime']
interventions[logical_index][display_cols]
# Out:
#      interventionId                        shortLabel  \
# 67             2770                               PAP
# 77             2899            Pressure Areas Intact?
# 117            2946   Pre-Op Diastolic Blood Pressure
# 119            2948    Pre-Op Systolic Blood Pressure
# 146            2980         Systolic BP Limit (mmHg):
# 272            3133     Pressure Area Intact Variance
# 340            3218          Intra Abdominal Pressure
# 350            3244               PS/ASB (Above PEEP)
# 418            3363                               NBP
# 420            3367                               PPV
# 433            3386                Peak Insp Pressure
# 434            3387                  Plateau Pressure
# 438            3391          Set Inspiratory Pressure
# 454            3426            Transmembrane Pressure
# 456            3428          Return (Venous) Pressure
# 459            3431        Access (Arterial) Pressure
# 462            3434               Filter Pod Pressure
# 463            3435                     Pressure Drop
# 474            3446             Effluent Pod Pressure
# 481            3455              Mean Airway Pressure
# 490            3466                               CVP
# 517            3514      Pressure relieving mattress?
# 629            3935           IABP Augmented Systolic
# 633            4025                               CPP
# 657            5391    Pressure Ulcer Care Plan Done?
# 684            5420  Skin Assessed & Pressure Areas I
# 780            7794                               NBP
# 905           21039                               NBP
# 1115          29085                               CVP
# 1173          33794               Pre-Filter Pressure
# 1214          34867           Pressure areas assessed
# 1349          67118    Blood Pressure (Pre Procedure)
# 1352          67627   Blood Pressure (Post Procedure)
# 1462          68483    Estimated PA systolic pressure
# 1475          68496              LV systolic Function
# 1492          68559        Details of pressure damage
# 1506          68581  Does patient have pressure damag
# 1623          69063                     Pressure Sore
# 1641          69094             Blood Pressure stable
# 1677          69196  Pressure Ulcer Category validate
# 1678          69197            Pressure Ulcer present
# 1686          69205          Pressure Ulcer Treatment
# 1705          69230                    Pressure ulcer
# 1745          69535                               PWP
# 1943          71775                     Pressure Care
#
#                                               longLabel  numberOfPatients  \
# 67                            Pulmonary Artery Pressure           22644.0
# 77                               Pressure Areas Intact?           13467.0
# 117             Pre-Op Diastolic Blood Pressure (mmHg):           20205.0
# 119              Pre-Op Systolic Blood Pressure (mmHg):           20826.0
# 146                           Systolic BP Limit (mmHg):            6965.0
# 272                       Pressure Area Intact Variance            1045.0
# 340                            Intra Abdominal Pressure             602.0
# 350                   Pressure Support/ASB (Above PEEP)          411985.0
# 418                                     Non-Invasive BP          215133.0
# 420                            Pulse Pressure Variation             582.0
# 433                           Peak Inspiratory Pressure          570977.0
# 434                             Plateau Airway Pressure            1481.0
# 438                            Set Inspiratory Pressure           15430.0
# 454                              Transmembrane Pressure           58946.0
# 456                            Return (Venous) Pressure          265954.0
# 459                          Access (Arterial) Pressure          268314.0
# 462                                 Filter Pod Pressure           67386.0
# 463                                       Pressure Drop           57565.0
# 474                               Effluent Pod Pressure           64121.0
# 481                                Mean Airway Pressure          864141.0
# 490                             Central Venous Pressure          323268.0
# 517              Is pressure relieving mattress needed?             442.0
# 629                             IABP Augmented Systolic           17070.0
# 633                         Cerebral Perfusion Pressure              42.0
# 657      Pressure Ulcer Prevention Care Plan Completed?            4158.0
# 684              Skin Assessed & Pressure Areas Intact?            4453.0
# 780                                     Non-Invasive BP          647741.0
# 905                                     Non-Invasive BP         1737170.0
# 1115                            Central Venous Pressure          469135.0
# 1173                                Pre-Filter Pressure          195834.0
# 1214  Patients pressure areas assessed before discha...             690.0
# 1349                     Blood Pressure (Pre Procedure)            1882.0
# 1352                    Blood Pressure (Post Procedure)            1723.0
# 1462                     Estimated PA systolic pressure             106.0
# 1475                               LV systolic Function             336.0
# 1492                         Details of pressure damage             274.0
# 1506         Does the patient have any pressure damage?            3487.0
# 1623                                      Pressure Sore            3479.0
# 1641                              Blood Pressure stable              11.0
# 1677           Pressure Ulcer Category validated by TVN              32.0
# 1678                             Pressure Ulcer present              78.0
# 1686                           Pressure Ulcer Treatment              42.0
# 1705                                     Pressure ulcer            2922.0
# 1745                           Pulmonary Wedge Pressure              53.0
# 1943                                      Pressure Care            1775.0
#
#                firstChartTime           firstChartTime
# 67    2015-05-26 16:00:00.000  2015-05-26 16:00:00.000
# 77    2015-03-24 08:37:00.000  2015-03-24 08:37:00.000
# 117   2015-02-27 17:25:00.000  2015-02-27 17:25:00.000
# 119   2015-02-27 17:25:00.000  2015-02-27 17:25:00.000
# 146   2015-03-06 13:04:00.000  2015-03-06 13:04:00.000
# 272   2015-03-24 08:37:00.000  2015-03-24 08:37:00.000
# 340   2015-03-11 22:00:00.000  2015-03-11 22:00:00.000
# 350   2015-02-03 14:00:00.000  2015-02-03 14:00:00.000
# 418   2015-02-03 09:55:00.000  2015-02-03 09:55:00.000
# 420   2015-10-31 00:00:00.000  2015-10-31 00:00:00.000
# 433   2015-02-03 11:00:00.000  2015-02-03 11:00:00.000
# 434   2015-02-03 12:00:00.000  2015-02-03 12:00:00.000
# 438   2015-02-04 12:00:00.000  2015-02-04 12:00:00.000
# 454   2015-02-03 11:24:00.000  2015-02-03 11:24:00.000
# 456   2015-02-03 11:24:00.000  2015-02-03 11:24:00.000
# 459   2015-02-03 11:24:00.000  2015-02-03 11:24:00.000
# 462   2015-02-03 11:24:00.000  2015-02-03 11:24:00.000
# 463   2015-02-03 11:24:00.000  2015-02-03 11:24:00.000
# 474   2015-02-03 12:00:00.000  2015-02-03 12:00:00.000
# 481   2015-02-03 11:00:00.000  2015-02-03 11:00:00.000
# 490   2015-02-03 09:39:00.000  2015-02-03 09:39:00.000
# 517   2015-02-05 13:01:00.000  2015-02-05 13:01:00.000
# 629   2015-03-27 02:00:00.000  2015-03-27 02:00:00.000
# 633   2020-09-21 00:00:00.000  2020-09-21 00:00:00.000
# 657   2015-03-24 12:36:00.000  2015-03-24 12:36:00.000
# 684   2015-03-24 12:36:00.000  2015-03-24 12:36:00.000
# 780   2015-06-15 12:41:00.000  2015-06-15 12:41:00.000
# 905   2016-11-28 19:00:00.000  2016-11-28 19:00:00.000
# 1115  2017-11-16 19:30:00.000  2017-11-16 19:30:00.000
# 1173  2018-06-30 16:00:00.000  2018-06-30 16:00:00.000
# 1214  2018-09-17 10:03:00.000  2018-09-17 10:03:00.000
# 1349  2019-09-17 14:49:00.000  2019-09-17 14:49:00.000
# 1352  2019-09-17 14:49:00.000  2019-09-17 14:49:00.000
# 1462  2020-01-29 09:48:00.000  2020-01-29 09:48:00.000
# 1475  2020-01-21 14:07:00.000  2020-01-21 14:07:00.000
# 1492  2020-01-30 02:43:00.000  2020-01-30 02:43:00.000
# 1506  2020-01-30 02:43:00.000  2020-01-30 02:43:00.000
# 1623  2020-07-07 14:30:00.000  2020-07-07 14:30:00.000
# 1641  2020-09-14 23:46:00.000  2020-09-14 23:46:00.000
# 1677  2020-09-15 12:33:00.000  2020-09-15 12:33:00.000
# 1678  2020-09-15 12:33:00.000  2020-09-15 12:33:00.000
# 1686  2020-09-15 12:33:00.000  2020-09-15 12:33:00.000
# 1705  2020-08-25 15:20:00.000  2020-08-25 15:20:00.000
# 1745  2020-12-21 16:00:00.000  2020-12-21 16:00:00.000
# 1943  2022-10-18 14:34:00.000  2022-10-18 14:34:00.000

# %%
interventions.loc[145]
# Out:
# interventionId                          2978
# shortLabel            Management Plan Other:
# longLabel             Management Plan Other:
# conceptCode                      305260005.0
# numberOfPatients                      2872.0
# firstChartTime       2015-02-27 17:25:00.000
# lastChartTime        2023-08-09 16:55:00.000
# numberOfRecords                       2872.0
# minClinicalUnitId                        5.0
# maxClinicalUnitId                        8.0
# Name: 145, dtype: object

# %%
import sqlite3

# %%
con = sqlite3.connect('test.db')

# %%
df = pd.DataFrame({'a': 0}, index=[1,2,3])

# %%
df.to_sql('test', con, index=True, index_label='index')
# Out:
# 3

# %%
cur = con.cursor()
cur.execute(f"""
                UPDATE test
                SET a = 3
                WHERE "index" = 3; 
            """)
con.commit()
con.close()

# %%
con = sqlite3.connect('test.db')
pd.read_sql("SELECT * FROM test", con)
# Out:
#    index  a
# 0      1  0
# 1      2  1
# 2      3  3
